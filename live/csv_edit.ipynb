# %%
import pandas as pd

# %%
df = pd.read_csv('predictions_readable.csv')
df
# Out:
#     round           match_date       home_team       away_team  odds_home  \
# 0       1  2026-08-21 19:00:00         Arsenal        Coventry       1.77
# 1       1  2026-08-22 11:30:00            Hull      Man United       4.13
# 2       1  2026-08-22 14:00:00         Everton  Crystal Palace       2.21
# 3       1  2026-08-22 14:00:00         Ipswich      Sunderland       2.96
# 4       1  2026-08-22 14:00:00   Nott'm Forest           Leeds       2.14
# 5       1  2026-08-22 16:30:00       Brentford       Tottenham       2.36
# 6       1  2026-08-23 13:00:00        Brighton     Aston Villa       2.22
# 7       1  2026-08-23 13:00:00        Man City     Bournemouth       1.84
# 8       1  2026-08-23 15:30:00       Newcastle       Liverpool       2.33
# 9       1  2026-08-24 19:00:00          Fulham         Chelsea       2.12
# 10      2  2026-08-28 19:00:00  Crystal Palace        Man City       3.44
# 11      2  2026-08-29 11:30:00       Liverpool   Nott'm Forest       1.92
# ...
